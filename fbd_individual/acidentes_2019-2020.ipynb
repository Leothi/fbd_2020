# %%
import pandas as pd
import numpy as np

import mysql.connector

from utils_text import strip_accents

# %%
def clean_text(string: str) -> str:
    string = string.lower()
    string = strip_accents(string)
    string = string.strip()
    
    return string

# %%
df_2019 = pd.read_csv('datatran2019.csv', encoding='latin1', sep=';')

# %%
df_2020 = pd.read_csv('datatran2020.csv', encoding='latin1', sep=';')

# %%
df = pd.concat([df_2019, df_2020])

# %%
df.head()
# Out:
#          id data_inversa   dia_semana   horario  uf     br     km  \
# 0  182210.0   2019-01-01  terça-feira  01:30:00  SP  116.0    218
# 1  182211.0   2019-01-01  terça-feira  01:30:00  PR  373.0  177,3
# 2  182212.0   2019-01-01  terça-feira  00:45:00  SC  101.0     16
# 3  182214.0   2019-01-01  terça-feira  00:00:00  CE   20.0  429,5
# 4  182215.0   2019-01-01  terça-feira  01:00:00  MG  381.0    327
#
#       municipio                       causa_acidente  \
# 0     GUARULHOS          Falta de Atenção à Condução
# 1  PONTA GROSSA          Falta de Atenção à Condução
# 2        GARUVA                     Animais na Pista
# 3     FORTALEZA  Ingestão de Substâncias Psicoativas
# 4      NOVA ERA          Falta de Atenção à Condução
#
#                  tipo_acidente  ... feridos_graves ilesos ignorados feridos  \
# 0  Colisão com objeto estático  ...              0      0         0       4
# 1             Colisão traseira  ...              0      0         0       1
# 2  Colisão com objeto estático  ...              0      0         0       1
# 3  Colisão com objeto estático  ...              1      0         0       1
# 4          Colisão transversal  ...              1      1         0       1
#
#   veiculos      latitude     longitude  regional  delegacia       uop
# 0        1  -23,46052014  -46,48772478     SR-SP     DEL6/1  UOP01/SP
# 1        1  -25,05533957  -50,22776753     SR-PR     DEL7/3  UOP01/PR
# 2        1      -26,1216      -48,8826     SR-SC     DEL8/3  UOP01/SC
# 3        1      -3,76999    -38,670063     SR-CE    DEL16/1  UOP02/CE
# 4        2      -19,7609      -43,0306     SR-MG     DEL4/3  UOP01/MG
#
# [5 rows x 30 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 83154 entries, 0 to 15707
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      83154 non-null  float64
#  1   data_inversa            83154 non-null  object
#  2   dia_semana              83154 non-null  object
#  3   horario                 83154 non-null  object
#  4   uf                      83154 non-null  object
#  5   br                      83033 non-null  float64
#  6   km                      83033 non-null  object
#  7   municipio               83154 non-null  object
#  8   causa_acidente          83154 non-null  object
#  9   tipo_acidente           83154 non-null  object
#  10  classificacao_acidente  83154 non-null  object
#  11  fase_dia                83154 non-null  object
#  12  sentido_via             83154 non-null  object
#  13  condicao_metereologica  83154 non-null  object
#  14  tipo_pista              83154 non-null  object
#  15  tracado_via             83154 non-null  object
#  16  uso_solo                83154 non-null  object
#  17  pessoas                 83154 non-null  int64
#  18  mortos                  83154 non-null  int64
#  19  feridos_leves           83154 non-null  int64
#  20  feridos_graves          83154 non-null  int64
#  21  ilesos                  83154 non-null  int64
#  22  ignorados               83154 non-null  int64
#  23  feridos                 83154 non-null  int64
#  24  veiculos                83154 non-null  int64
#  25  latitude                83154 non-null  object
#  26  longitude               83154 non-null  object
#  27  regional                83154 non-null  object
#  28  delegacia               83154 non-null  object
#  29  uop                     79318 non-null  object
# dtypes: float64(2), int64(8), object(20)
# memory usage: 19.7+ MB

# %%
colunas = ["id",
           "data_inversa",
           "horario",
           "uf",                                
           "br",              
           "km",                                
           "municipio",                         
           "causa_acidente",                    
           "tipo_acidente",                     
           "classificacao_acidente",            
           "fase_dia",                          
           "sentido_via",                       
           "condicao_metereologica",            
           "tipo_pista",                        
           "tracado_via",                       
           "pessoas",                            
           "mortos",                             
           "feridos_leves",                      
           "feridos_graves",                     
           "ilesos",                             
           "ignorados",                          
           "feridos",                            
           "veiculos"]

# %%
df = df[colunas]

# %%
df.head()
# Out:
#          id data_inversa   horario  uf     br     km     municipio  \
# 0  182210.0   2019-01-01  01:30:00  SP  116.0    218     GUARULHOS
# 1  182211.0   2019-01-01  01:30:00  PR  373.0  177,3  PONTA GROSSA
# 2  182212.0   2019-01-01  00:45:00  SC  101.0     16        GARUVA
# 3  182214.0   2019-01-01  00:00:00  CE   20.0  429,5     FORTALEZA
# 4  182215.0   2019-01-01  01:00:00  MG  381.0    327      NOVA ERA
#
#                         causa_acidente                tipo_acidente  \
# 0          Falta de Atenção à Condução  Colisão com objeto estático
# 1          Falta de Atenção à Condução             Colisão traseira
# 2                     Animais na Pista  Colisão com objeto estático
# 3  Ingestão de Substâncias Psicoativas  Colisão com objeto estático
# 4          Falta de Atenção à Condução          Colisão transversal
#
#   classificacao_acidente  ... tipo_pista         tracado_via pessoas mortos  \
# 0    Com Vítimas Feridas  ...   Múltipla               Curva       4      0
# 1    Com Vítimas Feridas  ...      Dupla                Reta       1      0
# 2    Com Vítimas Feridas  ...      Dupla                Reta       1      0
# 3    Com Vítimas Feridas  ...      Dupla             Viaduto       1      0
# 4    Com Vítimas Feridas  ...    Simples  Interseção de vias       2      0
#
#   feridos_leves  feridos_graves  ilesos  ignorados  feridos  veiculos
# 0             4               0       0          0        4         1
# 1             1               0       0          0        1         1
# 2             1               0       0          0        1         1
# 3             0               1       0          0        1         1
# 4             0               1       1          0        1         2
#
# [5 rows x 23 columns]

# %% [markdown]
# # Tratamento

# %%
# Tratamento/separação de tempo(dia)
df['data_hora'] = df['data_inversa'].map(str) + ' ' + df['horario']
df['data_hora'] = pd.to_datetime(df['data_hora'])
df['ano'] = df['data_hora'].dt.year
df['mes'] = df['data_hora'].dt.month
df['hora'] = df['data_hora'].dt.hour
df.drop(['data_inversa', 'horario'], axis=1, inplace = True)

# %%
df.head(3)
# Out:
#          id  uf     br     km     municipio               causa_acidente  \
# 0  182210.0  SP  116.0    218     GUARULHOS  Falta de Atenção à Condução
# 1  182211.0  PR  373.0  177,3  PONTA GROSSA  Falta de Atenção à Condução
# 2  182212.0  SC  101.0     16        GARUVA             Animais na Pista
#
#                  tipo_acidente classificacao_acidente     fase_dia  \
# 0  Colisão com objeto estático    Com Vítimas Feridas  Plena Noite
# 1             Colisão traseira    Com Vítimas Feridas  Plena Noite
# 2  Colisão com objeto estático    Com Vítimas Feridas  Plena Noite
#
#    sentido_via  ... feridos_leves feridos_graves ilesos  ignorados  feridos  \
# 0    Crescente  ...             4              0      0          0        4
# 1    Crescente  ...             1              0      0          0        1
# 2  Decrescente  ...             1              0      0          0        1
#
#    veiculos           data_hora   ano  mes  hora
# 0         1 2019-01-01 01:30:00  2019    1     1
# 1         1 2019-01-01 01:30:00  2019    1     1
# 2         1 2019-01-01 00:45:00  2019    1     0
#
# [3 rows x 25 columns]

# %%
# Drop de faltantes
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 83033 entries, 0 to 15707
# Data columns (total 25 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      83033 non-null  float64
#  1   uf                      83033 non-null  object
#  2   br                      83033 non-null  float64
#  3   km                      83033 non-null  object
#  4   municipio               83033 non-null  object
#  5   causa_acidente          83033 non-null  object
#  6   tipo_acidente           83033 non-null  object
#  7   classificacao_acidente  83033 non-null  object
#  8   fase_dia                83033 non-null  object
#  9   sentido_via             83033 non-null  object
#  10  condicao_metereologica  83033 non-null  object
#  11  tipo_pista              83033 non-null  object
#  12  tracado_via             83033 non-null  object
#  13  pessoas                 83033 non-null  int64
#  14  mortos                  83033 non-null  int64
#  15  feridos_leves           83033 non-null  int64
#  16  feridos_graves          83033 non-null  int64
#  17  ilesos                  83033 non-null  int64
#  18  ignorados               83033 non-null  int64
#  19  feridos                 83033 non-null  int64
#  20  veiculos                83033 non-null  int64
#  21  data_hora               83033 non-null  datetime64[ns]
#  22  ano                     83033 non-null  int64
#  23  mes                     83033 non-null  int64
#  24  hora                    83033 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(11), object(11)
# memory usage: 16.5+ MB

# %%
# Tratamento de texto: acentos e simbolos, lower case e strip
for column in df.columns:
    if df[column].dtypes == 'object':
        df[column] = df[column].apply(clean_text)

# %% [markdown]
# ### RESULTADO

# %%
df.head()
# Out:
#          id  uf     br     km     municipio  \
# 0  182210.0  sp  116.0    218     guarulhos
# 1  182211.0  pr  373.0  177,3  ponta grossa
# 2  182212.0  sc  101.0     16        garuva
# 3  182214.0  ce   20.0  429,5     fortaleza
# 4  182215.0  mg  381.0    327      nova era
#
#                         causa_acidente                tipo_acidente  \
# 0          falta de atencao a conducao  colisao com objeto estatico
# 1          falta de atencao a conducao             colisao traseira
# 2                     animais na pista  colisao com objeto estatico
# 3  ingestao de substancias psicoativas  colisao com objeto estatico
# 4          falta de atencao a conducao          colisao transversal
#
#   classificacao_acidente     fase_dia  sentido_via  ... feridos_leves  \
# 0    com vitimas feridas  plena noite    crescente  ...             4
# 1    com vitimas feridas  plena noite    crescente  ...             1
# 2    com vitimas feridas  plena noite  decrescente  ...             1
# 3    com vitimas feridas  plena noite  decrescente  ...             0
# 4    com vitimas feridas  plena noite  decrescente  ...             0
#
#   feridos_graves ilesos  ignorados  feridos  veiculos           data_hora  \
# 0              0      0          0        4         1 2019-01-01 01:30:00
# 1              0      0          0        1         1 2019-01-01 01:30:00
# 2              0      0          0        1         1 2019-01-01 00:45:00
# 3              1      0          0        1         1 2019-01-01 00:00:00
# 4              1      1          0        1         2 2019-01-01 01:00:00
#
#     ano  mes  hora
# 0  2019    1     1
# 1  2019    1     1
# 2  2019    1     0
# 3  2019    1     0
# 4  2019    1     1
#
# [5 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 83033 entries, 0 to 15707
# Data columns (total 25 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      83033 non-null  float64
#  1   uf                      83033 non-null  object
#  2   br                      83033 non-null  float64
#  3   km                      83033 non-null  object
#  4   municipio               83033 non-null  object
#  5   causa_acidente          83033 non-null  object
#  6   tipo_acidente           83033 non-null  object
#  7   classificacao_acidente  83033 non-null  object
#  8   fase_dia                83033 non-null  object
#  9   sentido_via             83033 non-null  object
#  10  condicao_metereologica  83033 non-null  object
#  11  tipo_pista              83033 non-null  object
#  12  tracado_via             83033 non-null  object
#  13  pessoas                 83033 non-null  int64
#  14  mortos                  83033 non-null  int64
#  15  feridos_leves           83033 non-null  int64
#  16  feridos_graves          83033 non-null  int64
#  17  ilesos                  83033 non-null  int64
#  18  ignorados               83033 non-null  int64
#  19  feridos                 83033 non-null  int64
#  20  veiculos                83033 non-null  int64
#  21  data_hora               83033 non-null  datetime64[ns]
#  22  ano                     83033 non-null  int64
#  23  mes                     83033 non-null  int64
#  24  hora                    83033 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(11), object(11)
# memory usage: 16.5+ MB

# %% [markdown]
# # Criação de DFs para ETL

# %%
# uf
df_uf = list(df['uf'].unique())
df_uf
# Out:
# ['sp',
#  'pr',
#  'sc',
#  'ce',
#  'mg',
#  'ms',
#  'go',
#  'rs',
#  'rj',
#  'pb',
#  'rn',
#  'pe',
#  'se',
#  'df',
#  'to',
#  'mt',
#  'es',
#  'ro',
#  'pa',
#  'al',
#  'am',
#  'ma',
#  'ba',
#  'pi',
#  'ap',
#  'rr',
#  'ac']

# %%
# municipio
df_municipio = list(df['municipio'].unique())
df_municipio
# Out:
# ['guarulhos',
#  'ponta grossa',
#  'garuva',
#  'fortaleza',
#  'nova era',
#  'gaspar',
#  'coxim',
#  'catalao',
#  'goiania',
#  'boa vista das missoes',
#  'uberlandia',
#  'ubatuba',
#  'maringa',
#  'betim',
#  'duque de caxias',
#  'cunha pora',
#  'cajazeiras',
#  'macaiba',
#  'natal',
#  'ipuiuna',
#  'angra dos reis',
#  'rio verde de mato grosso',
#  'douradina',
#  'sete lagoas',
#  'goiana',
#  'estancia',
#  'brasilia',
#  'joao pinheiro',
#  'papanduva',
#  'itaborai',
#  'indaial',
#  'tibagi',
#  'carlos barbosa',
#  'russas',
#  'gurupi',
#  'icara',
#  'igaratinga',
#  'rio verde',
#  'rosario do sul',
#  'campo bonito',
#  'agua boa',
#  'cascavel',
#  'sooretama',
#  'catingueira',
#  'ouro preto do oeste',
#  'dom eliseu',
#  'palhoca',
#  'diamantino',
#  'rio largo',
#  'itatiaiucu',
#  'porto velho',
#  'lages',
#  'manaus',
#  'caxias',
#  'rio real',
#  'formosa',
#  'maracanau',
#  'mangaratiba',
#  'tres forquilhas',
#  'domingos martins',
#  'sao paulo',
#  'cacimbinhas',
#  'oliveira fortes',
#  'amelia rodrigues',
#  'altos',
#  'feira de santana',
#  'araquari',
#  'mucuri',
#  'canoinhas',
#  'joao pessoa',
#  'lontras',
#  'torres',
#  'aguas lindas de goias',
#  'bocaina do sul',
#  'sao mateus',
#  'paranagua',
#  'porto alegre',
#  'igarape',
#  'guaraniacu',
#  'imperatriz',
#  'flores de goias',
#  'campo alegre de goias',
#  'maruim',
#  'biguacu',
#  'itapema',
#  'chapadinha',
#  'canguaretama',
#  'matelandia',
#  'apodi',
#  'vilhena',
#  'sao jose',
#  'registro',
#  'carmo da cachoeira',
#  'santo antonio do leverger',
#  'caucaia',
#  'viana',
#  'ibatiba',
#  'nova iguacu',
#  'itaguai',
#  'colinas do tocantins',
#  'petropolis',
#  'tijucas do sul',
#  'salinas',
#  'igarassu',
#  'santo antonio da patrulha',
#  'roseira',
#  'barbacena',
#  'barra mansa',
#  'palmeira',
#  'caridade',
#  'araguari',
#  'barra velha',
#  'jacarezinho',
#  'lavrinhas',
#  'gravatai',
#  'itaperuna',
#  'bom jesus do amparo',
#  'campo mourao',
#  'sao jose dos pinhais',
#  'curitiba',
#  'paulista',
#  'guarapuava',
#  'santa lucia',
#  'jeremoabo',
#  'balneario picarras',
#  'itapecerica da serra',
#  'joaquim gomes',
#  'nova serrana',
#  'sao luis',
#  'pirapora',
#  'petrolina',
#  'governador mangabeira',
#  'prata',
#  'juatuba',
#  'virmond',
#  'areal',
#  'abadiania',
#  'caetanopolis',
#  'cacapava do sul',
#  'osorio',
#  'jaguaribe',
#  'terra de areia',
#  'sapucaia',
#  'vacaria',
#  'recife',
#  'teresina',
#  'mundo novo',
#  'resende',
#  'pouso redondo',
#  'macapa',
#  'guarapari',
#  'vitoria da conquista',
#  'pariquera-acu',
#  'pescaria brava',
#  'campanario',
#  'itajai',
#  'pirai',
#  'ijui',
#  'camaqua',
#  'santa maria',
#  'jequie',
#  'campanha',
#  'fazenda vilanova',
#  'guaiba',
#  'paracatu',
#  'japeri',
#  'abre campo',
#  'bom retiro',
#  'areia branca',
#  'ico',
#  'parnaiba',
#  'uberaba',
#  'araguatins',
#  'cruz do espirito santo',
#  'cariacica',
#  'sao lourenco da serra',
#  'queluz',
#  'serrinha',
#  'extremoz',
#  'balsas',
#  'mossoro',
#  'valparaiso de goias',
#  'itabirito',
#  'serra',
#  'porto seguro',
#  'itajuipe',
#  'paraopeba',
#  'conceicao da barra',
#  'rio grande',
#  'curvelo',
#  'eldorado do sul',
#  'macae',
#  'canoas',
#  'bacabeira',
#  'curitibanos',
#  'concordia',
#  'santa izabel do para',
#  'guarai',
#  'pindamonhangaba',
#  'sabara',
#  'alfredo vasconcelos',
#  'arapongas',
#  'jatai',
#  'paraty',
#  'pranchita',
#  'campos dos goytacazes',
#  'teresopolis',
#  'nova alvorada do sul',
#  'linhares',
#  'barreiras',
#  'joinville',
#  'juquia',
#  'sao sebastiao de lagoa de  roca',
#  'brumadinho',
#  'sao bentinho',
#  'teixeira de freitas',
#  'rio pardo',
#  'niteroi',
#  'leopoldina',
#  'sao joao da fronteira',
#  'aracaju',
#  'campina grande do sul',
#  'eugenopolis',
#  'muriae',
#  'miradouro',
#  'colombo',
#  'nova santa rita',
#  'chorozinho',
#  'rio azul',
#  'mandaguari',
#  'monte carmelo',
#  'extrema',
#  'alegrete',
#  'cacoal',
#  'mage',
#  'contagem',
#  'porto belo',
#  'tijucas',
#  'ares',
#  'cariri do tocantins',
#  'blumenau',
#  'itapaje',
#  'campo largo',
#  'atibaia',
#  'xaxim',
#  'pilar',
#  'mafra',
#  'vargem',
#  'careacu',
#  'balneario camboriu',
#  'caico',
#  'araguaina',
#  'jaciara',
#  'bayeux',
#  'riachao do jacuipe',
#  'luz',
#  'fernandes pinheiro',
#  'sertania',
#  'caruaru',
#  'uruguaiana',
#  'floriano',
#  'montenegro',
#  'campos novos',
#  'sarandi',
#  'morro reuter',
#  'congonhas',
#  'caxias do sul',
#  'ji-parana',
#  'joao monlevade',
#  'parnamirim',
#  'mercedes',
#  'rio brilhante',
#  'seropedica',
#  'teodoro sampaio',
#  'cajati',
#  'morretes',
#  'fruta de leite',
#  'santiago',
#  'luziania',
#  'estrela',
#  'sao cristovao do sul',
#  'conselheiro lafaiete',
#  'bento goncalves',
#  'medina',
#  'tio hugo',
#  'mairipora',
#  'ribeirao das neves',
#  'laranjeiras do sul',
#  'acaua',
#  'ribeira do pombal',
#  'seabra',
#  'tiangua',
#  'oliveira dos brejinhos',
#  'taboao da serra',
#  'florianopolis',
#  'flores',
#  'porto real do colegio',
#  'apucarana',
#  'centralina',
#  'governador edison lobao',
#  'dois irmaos',
#  'sao lourenco do sul',
#  'ventania',
#  'padre bernardo',
#  'cruzeiro',
#  'fervedouro',
#  'guapimirim',
#  'terezopolis de goias',
#  'general carneiro',
#  'candido sales',
#  'aiuruoca',
#  'venturosa',
#  'sao joaquim de bicas',
#  'sao jose do rio preto',
#  'santo amaro da imperatriz',
#  'sao goncalo',
#  'boa vista',
#  'bela vista de minas',
#  'ubarana',
#  'malta',
#  'lavras',
#  'belo oriente',
#  'rio bonito',
#  'manhuacu',
#  'santa rita',
#  'pocos de caldas',
#  'taubate',
#  'paraibano',
#  'tabai',
#  'correia pinto',
#  'frutal',
#  'serra talhada',
#  'itamaraju',
#  'pedra preta',
#  'campos altos',
#  'santo antonio do amparo',
#  'buritizeiro',
#  'campo grande',
#  'itapeva',
#  'lajes',
#  'barra do pirai',
#  'soledade',
#  'tres coracoes',
#  'salvador',
#  'rondonopolis',
#  'barra do turvo',
#  'santa maria do para',
#  'simoes filho',
#  'silva jardim',
#  'guaratingueta',
#  'aruja',
#  'volta redonda',
#  'mandirituba',
#  'bocaiuva do sul',
#  'sao jose dos campos',
#  'aparecida de goiania',
#  'muzambinho',
#  'campo grande do piaui',
#  'prudentopolis',
#  'maravilha',
#  'aparecida',
#  'esteio',
#  'nova lima',
#  'maraba',
#  'ubaporanga',
#  'aracati',
#  'belo jardim',
#  'rancho queimado',
#  'londrina',
#  'perdoes',
#  'pouso alegre',
#  'alagoinhas',
#  'barra do corda',
#  'pinheiral',
#  'guaramirim',
#  'uruacu',
#  'sao francisco do sul',
#  'vitoria de santo antao',
#  'matupa',
#  'anapolis',
#  'monte alegre do piaui',
#  'ibirama',
#  'estrela de alagoas',
#  'lorena',
#  'milagres',
#  'novo hamburgo',
#  'goianapolis',
#  'atilio vivacqua',
#  'alvorada do norte',
#  'guaratuba',
#  'pontes e lacerda',
#  'aguas mornas',
#  'sorriso',
#  'sao leopoldo',
#  'alvorada doeste',
#  'colatina',
#  'belem de sao francisco',
#  'agua clara',
#  'rio branco',
#  'paulo lopes',
#  'embu das artes',
#  'picos',
#  'sao borja',
#  'juiz de fora',
#  'nova vicosa',
#  'antonina',
#  'para de minas',
#  'guaira',
#  'jaru',
#  'cristalina',
#  'comendador gomes',
#  'tres marias',
#  'santarem',
#  'irani',
#  'cabrobo',
#  'guaimbe',
#  'sao sebastiao do passe',
#  'ilheus',
#  'cabo de santo agostinho',
#  'maua da serra',
#  'iraucuba',
#  'codo',
#  'sao bento do sul',
#  'junqueiro',
#  'camanducaia',
#  'ponte serrada',
#  'ibipora',
#  'muitos capoes',
#  'tangua',
#  'buique',
#  'candeias do jamari',
#  'pocone',
#  'dourados',
#  'simolandia',
#  'guaranta do norte',
#  'barrolandia',
#  'ponto dos volantes',
#  'sao caitano',
#  'benevides',
#  'santa cecilia',
#  'nova itarana',
#  'marialva',
#  'caete',
#  'abreu e lima',
#  'alto araguaia',
#  'ibimirim',
#  'teofilo otoni',
#  'umirim',
#  'alianca do tocantins',
#  'fazenda rio grande',
#  'palmeira dos indios',
#  'bom sucesso',
#  'sao goncalo do rio abaixo',
#  'comodoro',
#  'amarante',
#  'porto uniao',
#  'aurelino leal',
#  'rio de janeiro',
#  'muquem de sao francisco',
#  'miracatu',
#  'sao joao do araguaia',
#  'felixlandia',
#  'campo florido',
#  'cachoeira do sul',
#  'candeias',
#  'patos de minas',
#  'nioaque',
#  'julio de castilhos',
#  'baependi',
#  'contenda',
#  'mirassol doeste',
#  'sao joao do manhuacu',
#  'piracanjuba',
#  'ipiau',
#  'pocoes',
#  'rio negrinho',
#  'laguna',
#  'bacabal',
#  'arcoverde',
#  'sinop',
#  'sao goncalo do amarante',
#  'coronel vivida',
#  'panelas',
#  'salvador do sul',
#  'itatiaia',
#  'rafael jambeiro',
#  'descanso',
#  'francisco sa',
#  'acailandia',
#  'itabaiana',
#  'maracaja',
#  'saldanha marinho',
#  'palmeiras',
#  'cachoeiro de itapemirim',
#  'corumba de goias',
#  'santo estevao',
#  'sao joao de meriti',
#  'wenceslau guimaraes',
#  'mamanguape',
#  'planalto',
#  'capixaba',
#  'lencois',
#  'braganca paulista',
#  'mallet',
#  'ribeirao',
#  'triunfo',
#  'salto grande',
#  'elesbao veloso',
#  'miranda',
#  'presidente medici',
#  'atalaia',
#  'eunapolis',
#  'irati',
#  'sao miguel do oeste',
#  'alexania',
#  'correntina',
#  'guararema',
#  'escada',
#  'santana do paraiso',
#  'bady bassitt',
#  'bandeirantes',
#  'sao cristovao',
#  'sangao',
#  'sao sebastiao da bela vista',
#  'nova mutum',
#  'ibiracu',
#  'senador jose bento',
#  'paranaiba',
#  'cacapava',
#  'demerval lobao',
#  'riachao do bacamarte',
#  'marilia',
#  'carmopolis de minas',
#  'queimados',
#  'luis correia',
#  'lucas do rio verde',
#  'cardoso moreira',
#  'ibateguara',
#  'campina grande',
#  'lapa',
#  'paragominas',
#  'porto vitoria',
#  'dom aquino',
#  'capao do leao',
#  'ituiutaba',
#  'rio dos bois',
#  'pocinhos',
#  'terra roxa',
#  'araucaria',
#  'japaratuba',
#  'itaquirai',
#  'venda nova do imigrante',
#  'palmeira das missoes',
#  'humaita',
#  'pombos',
#  'joao neiva',
#  'nova laranjeiras',
#  'jaboatao dos guararapes',
#  'cambui',
#  'rosario',
#  'moreno',
#  'conde',
#  'medianeira',
#  'balsa nova',
#  'arroio dos ratos',
#  'tubarao',
#  'juquitiba',
#  'santo antonio da barra',
#  'uniao dos palmares',
#  'anapu',
#  'itabela',
#  'peritoro',
#  'rodeio',
#  'roque gonzales',
#  'terenos',
#  'ipiranga',
#  'goiatuba',
#  'belo horizonte',
#  'sao jose do cerrito',
#  'passo de torres',
#  'sao goncalo do sapucai',
#  'quatro barras',
#  'jaguaracu',
#  'tururu',
#  'mato castelhano',
#  'ascurra',
#  'itabuna',
#  'barra do garcas',
#  'sousa',
#  'cassilandia',
#  'jose bonifacio',
#  'ararangua',
#  'sao mateus do sul',
#  'caseiros',
#  'mascote',
#  'coronel fabriciano',
#  'cuiaba',
#  'mucajai',
#  'foz do iguacu',
#  'patos',
#  'sao desiderio',
#  'santo antonio de jesus',
#  'peixoto de azevedo',
#  'santo antonio da platina',
#  'sao goncalo do gurgueia',
#  'uniao da vitoria',
#  'sao goncalo do abaete',
#  'porto real',
#  'porto esperidiao',
#  'caninde',
#  'sapucaia do sul',
#  'sao jose de mipibu',
#  'morada nova',
#  'marilandia do sul',
#  'pimenta bueno',
#  'arapora',
#  'maranguape',
#  'baixio',
#  'santana da boa vista',
#  'alvorada',
#  'talisma',
#  'lins',
#  'paula freitas',
#  'corrego danta',
#  'santa luzia',
#  'ortigueira',
#  'janiopolis',
#  'vitoria do xingu',
#  'santa ines',
#  'reboucas',
#  'onda verde',
#  'santos dumont',
#  'vila propicio',
#  'sao joao da barra',
#  'italva',
#  'gilbues',
#  'inhapim',
#  'cristinapolis',
#  'lindoeste',
#  'guaraciaba',
#  'jaraguari',
#  'barra do ribeiro',
#  'ibitiara',
#  'jaguaquara',
#  'ceu azul',
#  'sao marcos',
#  'canta',
#  'jardim',
#  'cachoeira de pajeu',
#  'paraiso do tocantins',
#  'oeiras',
#  'santa isabel',
#  'limoeiro do norte',
#  'pacajus',
#  'montes claros de goias',
#  'bom jesus',
#  'apiuna',
#  'santo antonio do descoberto',
#  'mormaco',
#  'quatro pontes',
#  'jacarei',
#  'canapolis',
#  'estrela do norte',
#  'urai',
#  'sao francisco do brejao',
#  'castanhal',
#  'francisco macedo',
#  'sombrio',
#  'varzea grande',
#  'ponte alta',
#  'governador valadares',
#  'garibaldi',
#  'alfredo wagner',
#  'pouso alto',
#  'pojuca',
#  'presidente figueiredo',
#  'nossa senhora do socorro',
#  'sobrado',
#  'gravata',
#  'oroco',
#  'tres cachoeiras',
#  'estancia velha',
#  'conquista doeste',
#  'aurora do para',
#  'sao vicente do sul',
#  'branquinha',
#  'irajuba',
#  'ceara-mirim',
#  'sao lourenco da mata',
#  'malhada dos bois',
#  'mimoso do sul',
#  'rio das ostras',
#  'sao gabriel do oeste',
#  'agua branca',
#  'salgueiro',
#  'sao gabriel',
#  'caravelas',
#  'lajeado',
#  'cabedelo',
#  'pedro canario',
#  'montes claros',
#  'primavera do leste',
#  'estiva',
#  'candoi',
#  'ourinhos',
#  'umbauba',
#  'amajari',
#  'erechim',
#  'porto grande',
#  'juscimeira',
#  'rolandia',
#  'taquaritinga do norte',
#  'laranjeiras',
#  'iconha',
#  'sao domingos do prata',
#  'agua santa',
#  'padre paraiso',
#  'trombudo central',
#  'caratinga',
#  'buriti dos lopes',
#  'marques de souza',
#  'ipaumirim',
#  'matipo',
#  'xanxere',
#  'anchieta',
#  'guapo',
#  'peixe',
#  'realeza',
#  'iati',
#  'itapecuru mirim',
#  'ibema',
#  'sao miguel de taipu',
#  'santa terezinha de itaipu',
#  'santa mariana',
#  'mae do rio',
#  'itaobim',
#  'jequitai',
#  'nova granada',
#  'oliveira',
#  'santa margarida do sul',
#  'passo fundo',
#  'pato branco',
#  'camacan',
#  'sao joao dos patos',
#  'itaberaba',
#  'itiquira',
#  'tres rios',
#  'cruz alta',
#  'fundao',
#  'ulianopolis',
#  'jaguare',
#  'olaria',
#  'navegantes',
#  'itapemirim',
#  'agua doce',
#  'sobral',
#  'corrente',
#  'mandaguacu',
#  'glorinha',
#  'alto paraiso',
#  'marechal candido rondon',
#  'ibirapitanga',
#  'itagimirim',
#  'piquete',
#  'professor jamil',
#  'pouso novo',
#  'capao alto',
#  'dom cavati',
#  'antonio dias',
#  'arataca',
#  'tres passos',
#  'fontoura xavier',
#  'vassouras',
#  'fortaleza do tabocao',
#  'santa rita de minas',
#  'bicas',
#  'adrianopolis',
#  'ubajara',
#  'bonfim',
#  'garanhuns',
#  'sao francisco de goias',
#  'paraiso das aguas',
#  'morrinhos',
#  'itambacuri',
#  'quitandinha',
#  'imbau',
#  'palmital',
#  'maracaju',
#  'forquilha',
#  'joacaba',
#  'rio do sul',
#  'carazinho',
#  'imbituba',
#  'tres lagoas',
#  'penha',
#  'santana do ipanema',
#  'bezerros',
#  'gurinhem',
#  'toledo',
#  'liberdade',
#  'barao de grajau',
#  'pelotas',
#  'imbituva',
#  'caarapo',
#  'trindade',
#  'maurilandia',
#  'poxoreo',
#  'marechal floriano',
#  'boa viagem',
#  'brasileira',
#  'belford roxo',
#  'agrestina',
#  'monsenhor gil',
#  'riachao',
#  'jataizinho',
#  'cachoeirinha',
#  'grao mogol',
#  'sao luis do curu',
#  'laje',
#  'sao miguel do guama',
#  'riachao das neves',
#  'cezarina',
#  'sidrolandia',
#  'itaguara',
#  'promissao',
#  'panama',
#  'itauba',
#  'alto garcas',
#  'piraquara',
#  'porto murtinho',
#  'catuji',
#  'palmeiras do tocantins',
#  'santa barbara',
#  'bage',
#  'santa rosa do sul',
#  'aracruz',
#  'camapua',
#  'muribeca',
#  'moema',
#  'santo antonio das missoes',
#  'santo antonio de lisboa',
#  'barao de cocais',
#  'santa rita do araguaia',
#  'hidrolandia',
#  'jampruca',
#  'vila velha',
#  'sao miguel do iguacu',
#  'mambore',
#  'rio casca',
#  'catanduvas',
#  'alhandra',
#  'sao joao do rio do peixe',
#  'santa cruz do sul',
#  'itatim',
#  'jatoba',
#  'nobres',
#  'vargem bonita',
#  'guimarania',
#  'vitoria',
#  'nova uniao',
#  'viseu',
#  'santa cruz',
#  'mateus leme',
#  'monte alegre de minas',
#  'cornelio procopio',
#  'campo redondo',
#  'vila flores',
#  'jati',
#  'jandaia',
#  'sao goncalo do para',
#  'caapora',
#  'pejucara',
#  'carira',
#  'paudalho',
#  'nazare',
#  'eusebio',
#  'jardim do serido',
#  'claudia',
#  'itaja',
#  'juazeiro',
#  'abadia de goias',
#  'cambe',
#  'fronteira',
#  'horizonte',
#  'chapeco',
#  'santa luzia do itanhy',
#  'tacaimbo',
#  'cerro largo',
#  'ponta pora',
#  'lajeado novo',
#  'anastacio',
#  'cumari',
#  'carvalhos',
#  'caldas',
#  'romaria',
#  'corupa',
#  'riachuelo',
#  'porto franco',
#  'ouro preto',
#  'bela vista do maranhao',
#  'chui',
#  'pirenopolis',
#  'santana do livramento',
#  'beberibe',
#  'cangucu',
#  'cedro de sao joao',
#  'agronomica',
#  'ocaucu',
#  'sao simao',
#  'bertolinia',
#  'barro',
#  'ipixuna do para',
#  'rafael fernandes',
#  'capivari de baixo',
#  'rio novo do sul',
#  'barracao',
#  'ponto novo',
#  'casimiro de abreu',
#  'canas',
#  'bonito',
#  'ivoti',
#  'nova olinda',
#  'arari',
#  'carai',
#  'sao jose do belmonte',
#  'santa maria da boa vista',
#  'catu',
#  'gandu',
#  'mineiros',
#  'palmares',
#  'pantano grande',
#  'ariquemes',
#  'fatima',
#  'ferreira gomes',
#  'ipojuca',
#  'paranavai',
#  'naque',
#  'presidente kennedy',
#  'porangatu',
#  'piracuruca',
#  'sao sepe',
#  'campo maior',
#  'jaragua',
#  'terra nova do norte',
#  'bom jesus de goias',
#  'santa tereza de goias',
#  'itapebi',
#  'andira',
#  'navirai',
#  'tuneiras do oeste',
#  'iuna',
#  'guamiranga',
#  'alem paraiba',
#  'caicara do rio do vento',
#  'sao miguel do guapore',
#  'capanema',
#  'medicilandia',
#  'maribondo',
#  'timon',
#  'indianopolis',
#  'candeal',
#  'tanquinho',
#  'davinopolis',
#  'canapi',
#  'dionisio cerqueira',
#  'boa vista do burica',
#  'sena madureira',
#  'cocalzinho de goias',
#  'cantagalo',
#  'sao joao do soter',
#  'juranda',
#  'barao de cotegipe',
#  'conceicao do jacuipe',
#  'pesqueira',
#  'grajau',
#  'pombal',
#  'novo lino',
#  'conceicao de macabu',
#  'marquinho',
#  'pinhalzinho',
#  'miranda do norte',
#  'tracunhaem',
#  'monte alegre dos campos',
#  'itaitinga',
#  'picada cafe',
#  'santa luz',
#  'criciuma',
#  'vereda',
#  'poco branco',
#  'petrolandia',
#  'dois irmaos do buriti',
#  'francisco ayres',
#  'sao francisco do gloria',
#  'araxa',
#  'lagoa vermelha',
#  'jaragua do sul',
#  'matoes do norte',
#  'sao jose do cedro',
#  'silveiras',
#  'veranopolis',
#  ...]

# %%
# causa_acidente
df_causa_acidente = list(df['causa_acidente'].unique())
df_causa_acidente
# Out:
# ['falta de atencao a conducao',
#  'animais na pista',
#  'ingestao de substancias psicoativas',
#  'desobediencia as normas de transito pelo condutor',
#  'desobediencia as normas de transito pelo pedestre',
#  'ingestao de alcool',
#  'velocidade incompativel',
#  'ingestao de alcool e/ou substancias psicoativas pelo pedestre',
#  'pista escorregadia',
#  'condutor dormindo',
#  'defeito mecanico no veiculo',
#  'sinalizacao da via insuficiente ou inadequada',
#  'defeito na via',
#  'nao guardar distancia de seguranca',
#  'objeto estatico sobre o leito carrocavel',
#  'restricao de visibilidade',
#  'falta de atencao do pedestre',
#  'ultrapassagem indevida',
#  'avarias e/ou desgaste excessivo no pneu',
#  'mal subito',
#  'agressao externa',
#  'carga excessiva e/ou mal acondicionada',
#  'fenomenos da natureza',
#  'deficiencia ou nao acionamento do sistema de iluminacao/sinalizacao do veiculo']

# %%
# tipo_acidente
df_tipo_acidente = list(df['tipo_acidente'].unique())
df_tipo_acidente
# Out:
# ['colisao com objeto estatico',
#  'colisao traseira',
#  'colisao transversal',
#  'saida de leito carrocavel',
#  'atropelamento de animal',
#  'atropelamento de pedestre',
#  'colisao frontal',
#  'colisao lateral',
#  'queda de ocupante de veiculo',
#  'incendio',
#  'capotamento',
#  'engavetamento',
#  'tombamento',
#  'derramamento de carga',
#  'colisao com objeto em movimento',
#  'danos eventuais']

# %%
# classificacao_acidente
df_classificacao_acidente = list(df['classificacao_acidente'].unique())
df_classificacao_acidente
# Out:
# ['com vitimas feridas', 'sem vitimas', 'com vitimas fatais']

# %%
# fase_dia
df_fase_dia = list(df['fase_dia'].unique())
df_fase_dia
# Out:
# ['plena noite', 'amanhecer', 'pleno dia', 'anoitecer']

# %%
# sentido_via
df_sentido_via = list(df['sentido_via'].unique())
df_sentido_via
# Out:
# ['crescente', 'decrescente']

# %%
# condicao_metereologica
df_condicao_metereologica = list(df['condicao_metereologica'].unique())
df_condicao_metereologica
# Out:
# ['ceu claro',
#  'nublado',
#  'chuva',
#  'garoa/chuvisco',
#  'ignorado',
#  'nevoeiro/neblina',
#  'vento',
#  'sol',
#  'granizo',
#  'neve']

# %%
# tipo_pista
df_tipo_pista = list(df['tipo_pista'].unique())
df_tipo_pista
# Out:
# ['multipla', 'dupla', 'simples']

# %%
# tracado_via
df_tracado_via = list(df['tracado_via'].unique())
df_tracado_via
# Out:
# ['curva',
#  'reta',
#  'viaduto',
#  'intersecao de vias',
#  'nao informado',
#  'rotatoria',
#  'desvio temporario',
#  'retorno regulamentado',
#  'tunel',
#  'ponte']

# %% [markdown]
# ### DF FINAL

# %%
df_final = df.copy()
df_final = df_final.drop('ano', axis=1)
df_final = df_final.drop('mes', axis=1)
df_final = df_final.drop('hora', axis=1)
df_final = df_final.reset_index(drop=True)

# %%
# Troca de , para . nos numeros nao inteiros
df_final['km'] = df_final['km'].apply(lambda x: float(x.replace(',','.')))

# %%
dict_df = {'uf': df_uf,
           'municipio': df_municipio,
           'causa_acidente': df_causa_acidente,
           'tipo_acidente': df_tipo_acidente,
           'classificacao_acidente': df_classificacao_acidente,
           'fase_dia': df_fase_dia,
           'sentido_via': df_sentido_via,
           'condicao_metereologica': df_condicao_metereologica,
           'tipo_pista': df_tipo_pista,
           'tracado_via': df_tracado_via}

# %%
for column in list(dict_df.keys()):
    for i, value in enumerate(df[column]):
        index = dict_df[column].index(value)
        index +=1
        df_final[column][i] = index
# Out:
# <ipython-input-31-287be7b1512e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final[column][i] = index

# %%
df_final.head()
# Out:
#          id uf     br     km municipio causa_acidente tipo_acidente  \
# 0  182210.0  1  116.0  218.0         1              1             1
# 1  182211.0  2  373.0  177.3         2              1             2
# 2  182212.0  3  101.0   16.0         3              2             1
# 3  182214.0  4   20.0  429.5         4              3             1
# 4  182215.0  5  381.0  327.0         5              1             3
#
#   classificacao_acidente fase_dia sentido_via  ... tracado_via pessoas mortos  \
# 0                      1        1           1  ...           1       4      0
# 1                      1        1           1  ...           2       1      0
# 2                      1        1           2  ...           2       1      0
# 3                      1        1           2  ...           3       1      0
# 4                      1        1           2  ...           4       2      0
#
#    feridos_leves  feridos_graves  ilesos  ignorados  feridos  veiculos  \
# 0              4               0       0          0        4         1
# 1              1               0       0          0        1         1
# 2              1               0       0          0        1         1
# 3              0               1       0          0        1         1
# 4              0               1       1          0        1         2
#
#             data_hora
# 0 2019-01-01 01:30:00
# 1 2019-01-01 01:30:00
# 2 2019-01-01 00:45:00
# 3 2019-01-01 00:00:00
# 4 2019-01-01 01:00:00
#
# [5 rows x 22 columns]

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83033 entries, 0 to 83032
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      83033 non-null  float64
#  1   uf                      83033 non-null  object
#  2   br                      83033 non-null  float64
#  3   km                      83033 non-null  float64
#  4   municipio               83033 non-null  object
#  5   causa_acidente          83033 non-null  object
#  6   tipo_acidente           83033 non-null  object
#  7   classificacao_acidente  83033 non-null  object
#  8   fase_dia                83033 non-null  object
#  9   sentido_via             83033 non-null  object
#  10  condicao_metereologica  83033 non-null  object
#  11  tipo_pista              83033 non-null  object
#  12  tracado_via             83033 non-null  object
#  13  pessoas                 83033 non-null  int64
#  14  mortos                  83033 non-null  int64
#  15  feridos_leves           83033 non-null  int64
#  16  feridos_graves          83033 non-null  int64
#  17  ilesos                  83033 non-null  int64
#  18  ignorados               83033 non-null  int64
#  19  feridos                 83033 non-null  int64
#  20  veiculos                83033 non-null  int64
#  21  data_hora               83033 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(3), int64(8), object(10)
# memory usage: 13.9+ MB

# %% [markdown]
# # ETL

# %%
cnx = mysql.connector.connect(user='root', password='root',
                              host='localhost',
                              database='acidentes_db')

# %%
cursor = cnx.cursor()

# %%
dict_colunas = {'CAUSA_ACIDENTE': df_causa_acidente,
                'CLF_ACIDENTE': df_classificacao_acidente, 
                'COND_METEREOLOGICA': df_condicao_metereologica, 
                'FASE_DIA': df_fase_dia, 
                'MUNICIPIO': df_municipio, 
                'SENTIDO_VIA': df_sentido_via, 
                'TIPO_ACIDENTE': df_tipo_acidente, 
                'TIPO_PISTA': df_tipo_pista, 
                'UF': df_uf, 
                'TRACADO_VIA': df_tracado_via}

# %%
# Colunas normais
for name, df in dict_colunas.items():
    for value in df:
        query = f"INSERT INTO {name} "\
                 f"(NOME)" \
                 f"VALUES ({value!r})"
        cursor.execute(query)

# %%
cnx.commit()

# %%
# Coluna acidente
for index, name in df_final.iterrows():
    query = f"INSERT INTO ACIDENTE"\
                 f"(ID_ACIDENTE, ID_UF, BR, KM, ID_MUNICIPIO, ID_CAUSA_ACIDENTE, ID_TIPO_ACIDENTE, ID_CLF_ACIDENTE, ID_FASE_DIA, ID_SENTIDO_VIA, ID_COND_METEREOLOGICA, ID_TIPO_PISTA, ID_TRACADO_VIA, NUM_PESSOAS, NUM_MORTOS, NUM_FERIDOS_LEVES, NUM_FERIDOS_GRAVES, NUM_ILESOS, NUM_IGNORADOS, NUM_FERIDOS, NUM_VEICULOS, DATA)" \
                 f"VALUES ({name['id']!r}, {name['uf']!r}, {name['br']!r},{name['km']!r}, {name['municipio']!r}, {name['causa_acidente']!r}, {name['tipo_acidente']!r}, {name['classificacao_acidente']!r}, {name['fase_dia']!r}, {name['sentido_via']!r}, {name['condicao_metereologica']!r}, {name['tipo_pista']!r}, {name['tracado_via']!r}, {name['pessoas']!r}, {name['mortos']!r}, {name['feridos_leves']!r}, {name['feridos_graves']!r}, {name['ilesos']!r}, {name['ignorados']!r}, {name['feridos']!r}, {name['veiculos']!r}, {name['data_hora']!r})"
    cursor.execute(query)

# %%
cnx.commit()

# %%
cnx.close()
